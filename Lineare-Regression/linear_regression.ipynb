# %% [markdown]
# Bei einem Regressionsproblem besteht das Ziel darin, die Ausgabe eines kontinuierlichen Wertes, wie eines Preises oder einer Wahrscheinlichkeit, vorherzusagen.
# Im Gegensatz dazu gibt es das Klassifizierungsproblem wo es darum geht, eine Klasse aus einer Liste von Klassen auszuwählen (z.B wenn ein Bild einen Apfel oder eine Orange enthält, zu erkennen welche Frucht auf dem Bild zu sehen ist).

# %%
# Use seaborn for pairplot
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Use seaborn for pairplot
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'
